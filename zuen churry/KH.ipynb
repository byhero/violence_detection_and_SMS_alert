# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ns_df = pd.read_excel('1.xlsx') 
ns_df.rename(columns={"NS Shop+ 2019.01.01~12.31"	:"time","Unnamed: 1":"playtime","Unnamed: 2":"code","Unnamed: 3":"productcode","Unnamed: 4":"name","Unnamed: 5":"category","Unnamed: 6":"price","Unnamed: 7":"output"},inplace=True)
ns_df.drop([0], inplace=True)

ns_df_list=np.array(ns_df.values.tolist())  ## 1데이터 리스트로 변환

ns_df['time']=pd.to_datetime(ns_df['time'])
ns_df.head()
# Out:
#                  time playtime    code productcode           name category  \
# 1 2019-01-01 06:00:00       20  100346      201072  테이트 남성 셀린니트3종       의류
# 2 2019-01-01 06:00:00      NaN  100346      201079  테이트 여성 셀린니트3종       의류
# 3 2019-01-01 06:20:00       20  100346      201072  테이트 남성 셀린니트3종       의류
# 4 2019-01-01 06:20:00      NaN  100346      201079  테이트 여성 셀린니트3종       의류
# 5 2019-01-01 06:40:00       20  100346      201072  테이트 남성 셀린니트3종       의류
#
#    price   output
# 1  39900  2099000
# 2  39900  4371000
# 3  39900  3262000
# 4  39900  6955000
# 5  39900  6672000

# %%
watch = pd.read_excel('watch.xlsx')      #2데이터

watch=watch.T
watch.head()
# Out:
#              0      1      2      3      4      5      6      7      8     \
# 시간대         02:00  02:01  02:02  02:03  02:04  02:05  02:06  02:07  02:08
# 2019-01-01      0      0      0      0      0      0      0      0      0
# 2019-01-02      0      0      0      0      0      0      0      0      0
# 2019-01-03      0      0      0  0.014      0      0      0      0      0
# 2019-01-04      0      0      0      0      0      0      0      0      0
#
#              9     ...   1431   1432   1433   1434   1435   1436   1437  \
# 시간대         02:09  ...  01:51  01:52  01:53  01:54  01:55  01:56  01:57
# 2019-01-01  0.014  ...      0      0      0      0      0      0      0
# 2019-01-02      0  ...      0      0      0      0      0      0      0
# 2019-01-03      0  ...      0      0      0      0      0      0      0
# 2019-01-04      0  ...      0      0      0      0      0      0      0
#
#              1438   1439                1440
# ...

# %%
watch_list=watch.values.tolist()

watch_list=np.array(watch_list)        #watch데이터 프레임 리스트로 변경
watch_list=watch_list[1:,:]


watch_list=watch_list.astype(np.float64) 
watch_list#안에 값만 추출
# Out:
# array([[0.   , 0.   , 0.   , ..., 0.   , 0.   , 0.004],
#        [0.   , 0.   , 0.   , ..., 0.   , 0.   , 0.006],
#        [0.   , 0.   , 0.   , ..., 0.   , 0.   , 0.002],
#        ...,
#        [0.   , 0.   , 0.   , ..., 0.019, 0.   , 0.005],
#        [0.   , 0.012, 0.   , ..., 0.   , 0.   , 0.005],
#        [0.003, 0.003, 0.004, ..., 0.004, 0.004, 0.004]])

# %%
ns_df_na=ns_df.fillna(0)    #na값 0으로 채웟
ns_df_na_list=np.array(ns_df_na.values.tolist())
playtime_na=ns_df_na_list[:,1]  
playtime_na=playtime_na.astype(np.int64) #방송시간만 int로 추출
playtime_na
# Out:
# array([20,  0, 20, ..., 20, 20, 17], dtype=int64)

# %%
cnt=0
for x in range(np.shape(playtime)[0]):
    if (playtime_na[x]%10!=0):
        print(x,playtime_na[x])                ##방송시간이 10의배수로 안떨어지는 것들 확인
        cnt+=1
cnt
# Out:
# 66 17
# 170 17
# 265 17
# 349 17
# 446 17
# 532 17
# 621 17
# 720 17
# 800 17
# 895 17
# 987 17
# 1094 17
# 1198 17
# 1277 17
# 1392 17
# 1485 27
# 1574 16
# 1651 16
# 1764 16
# 1887 16
# 1975 26
# 2087 16
# 2175 16
# 2269 16
# 2360 16
# 2432 16
# 2534 16
# 2613 16
# 2684 16
# 2803 16
# 2886 16
# 2974 16
# 3080 16
# 3191 16
# 3272 16
# 3383 16
# 3503 16
# 3598 16
# 3707 16
# 3810 16
# 3912 16
# 3977 16
# 4085 16
# 4188 16
# 4286 16
# 4406 16
# 4504 16
# 4610 16
# 4724 16
# 4830 16
# 4936 16
# 5047 26
# 5136 16
# 5217 16
# 5343 16
# 5423 16
# 5510 16
# 5590 16
# 5704 16
# 5816 16
# 5930 26
# 5961 12
# 6048 16
# 6153 16
# 6265 16
# 6377 16
# 6472 16
# 6577 15
# 6675 16
# 6690 2
# 6793 16
# 6881 16
# 7001 16
# 7120 15
# 7226 15
# 7324 15
# 7411 15
# 7515 16
# 7612 15
# 7722 15
# 7824 25
# 7931 16
# 8028 16
# 8146 16
# 8253 16
# 8361 16
# 8443 16
# 8535 26
# 8637 16
# 8743 16
# 8863 16
# 8880 25
# 9127 16
# 9238 14
# 9366 24
# 9488 14
# 9537 2
# 9601 14
# 9731 14
# 9875 14
# 9997 14
# ...

# %%
time=ns_df_list[:,0]  #타임 열 추출
playtime=ns_df_list[:,1]  #nan포함 playtime 추출

# %%
nan_list_playtime = np.array([])
for x in range(np.shape(playtime)[0]):
    if (np.isnan(playtime[x])):
        arr = np.append(arr, np.array(plat))                                  #playtime nan의 위치 확인

# %%
time
# Out:
# array([datetime.datetime(2019, 1, 1, 6, 0),
#        datetime.datetime(2019, 1, 1, 6, 0),
#        datetime.datetime(2019, 1, 1, 6, 20), ...,
#        datetime.datetime(2020, 1, 1, 1, 0),
#        datetime.datetime(2020, 1, 1, 1, 20),
#        datetime.datetime(2020, 1, 1, 1, 40)], dtype=object)

# %%
code=ns_df_na_list[:,2]  
code=code.astype(np.int64)
code.shape                             #마더코드 리스트
# Out:
# (38309,)

# %%
cnt=0
before=0
for i in range(38309):
    if code[i-1]!=code[i]:
        print("%d ~ %d 까지 같은 방송 " %(before+3,(i+2))) #엑셀 행 번호 기준
        before=i
        
        cnt+=1
cnt #7523번의 방송횟수  마지막방송 38309~38311같은것 빼고 다 표시
# Out:
# 3 ~ 2 까지 같은 방송
# 3 ~ 8 까지 같은 방송
# 9 ~ 11 까지 같은 방송
# 12 ~ 14 까지 같은 방송
# 15 ~ 17 까지 같은 방송
# 18 ~ 20 까지 같은 방송
# 21 ~ 22 까지 같은 방송
# 23 ~ 25 까지 같은 방송
# 26 ~ 27 까지 같은 방송
# 28 ~ 31 까지 같은 방송
# 32 ~ 34 까지 같은 방송
# 35 ~ 36 까지 같은 방송
# 37 ~ 37 까지 같은 방송
# 38 ~ 40 까지 같은 방송
# 41 ~ 43 까지 같은 방송
# 44 ~ 46 까지 같은 방송
# 47 ~ 52 까지 같은 방송
# 53 ~ 55 까지 같은 방송
# 56 ~ 57 까지 같은 방송
# 58 ~ 60 까지 같은 방송
# 61 ~ 66 까지 같은 방송
# 67 ~ 69 까지 같은 방송
# 70 ~ 72 까지 같은 방송
# 73 ~ 75 까지 같은 방송
# 76 ~ 78 까지 같은 방송
# 79 ~ 81 까지 같은 방송
# 82 ~ 93 까지 같은 방송
# 94 ~ 95 까지 같은 방송
# 96 ~ 107 까지 같은 방송
# 108 ~ 110 까지 같은 방송
# 111 ~ 112 까지 같은 방송
# 113 ~ 115 까지 같은 방송
# 116 ~ 121 까지 같은 방송
# 122 ~ 124 까지 같은 방송
# 125 ~ 127 까지 같은 방송
# 128 ~ 130 까지 같은 방송
# 131 ~ 139 까지 같은 방송
# 140 ~ 145 까지 같은 방송
# 146 ~ 163 까지 같은 방송
# 164 ~ 166 까지 같은 방송
# 167 ~ 170 까지 같은 방송
# 171 ~ 173 까지 같은 방송
# 174 ~ 179 까지 같은 방송
# 180 ~ 182 까지 같은 방송
# 183 ~ 185 까지 같은 방송
# 186 ~ 188 까지 같은 방송
# 189 ~ 190 까지 같은 방송
# 191 ~ 193 까지 같은 방송
# 194 ~ 196 까지 같은 방송
# 197 ~ 199 까지 같은 방송
# ...
